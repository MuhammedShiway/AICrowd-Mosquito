# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammedShiway/AICrowd-Mosquito/blob/main/SEABORN_Presentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORT NECESSARY LIBRARIES

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn.objects as so

# %%
sns.__version__
# Out:
# '0.12.2'

# %% [markdown]
# # LOAD NEEDED DATA

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
dowjones = sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %% [markdown]
# # LET'S PLOT

# %%
# Apply the default theme
sns.set_theme()

# %%
sns.pairplot(penguins, hue="species")

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
#sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack", kind="kde")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %%
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %% [markdown]
# # MULTIPLE PLOTS

# %%
# FACET GRID

# %%
# HEATMAP

# %%
# PAIRPLOT

# %% [markdown]
# # COMPARATIVE TESTS

# %%
plt.hist(penguins['flipper_length_mm'], bins=20, color='blue')
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Frequency')
# plt.show()
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.histplot(penguins, x='flipper_length_mm', bins=20, color='blue')
# plt.show()
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
corr = penguins.corr()

plt.imshow(corr, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(np.arange(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(np.arange(len(corr.columns)), corr.columns)

# Display the plot
plt.title('Penguins Dataset Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-29-badebd3b27f6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = penguins.corr()

# %%
corr = penguins.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <ipython-input-31-cc9ad6190695>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = penguins.corr()
# <Axes: >
